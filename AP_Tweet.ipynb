# %%
# !pip install tweepy

# %%
#import files and give access to tokens and keys
import tweepy as tw
import json
access_token="3887479519-O5WMmzYE0xvJ43Z6ECf5j5xW0Cy8RO064BWKMdh"
access_token_secret="DM1CO0ELMYuI9qfWbcKotdEbQrPOukbSPguFZBXPu7i7x"
consumer_key="ymr1st26elWU73m8C3OkTfiW1"
consumer_secret="FvCkAEgamsKsMueI0gMZyewZasYZsFMrZmVEGTER76uFR8XJzg"

# %%
auth = tw.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tw.API(auth, wait_on_rate_limit=True)

# %%
new_search = "crypto"

tweets = tw.Cursor(api.search_tweets,
                   q=new_search,
                   lang="en",
                ).items(1000)

all_tweets = [tweet.text for tweet in tweets]
all_tweets[:200]
# Out:
# Rate limit reached. Sleeping for: 842
# ['RT @CryptoTalkzInfo: Crypto Talkz will host AMA with MeyChain on 20th June 2022 at 12:00 PM UTC \n\n💰Rewards Pool : $300 MeyChain\n\n🏠Venue : h…',
#  'RT @HighyieldHarry: Matt Damon to everyone he got into crypto last year:  https://t.co/k17bA02GUZ',
#  'RT @HighyieldHarry: Matt Damon to everyone he got into crypto last year:  https://t.co/k17bA02GUZ',
#  "In Africa, there's an immense opportunity for #crypto tech to piggyback on mobile money's success. The results of i… https://t.co/Tvst5SQKCB",
#  'RT @nepp1963: Selling this great 1/1 NFT for just $1. Check it out! Tnx! :-)\n\nhttps://t.co/71QQZRv5dM',
#  '@OfficialJVK @shivamchhuneja Top 98-99% shitcoins in all crypto, bottom #btc',
#  'RT @LilMoonLambo: Chief Keef coding Bitcoin, 2008 https://t.co/1jjGe6Wwyd',
#  'New Defi project, Gas Fee = Gas Free?\n@brinefinance #brinefinance #crypto #web3',
# ...

# %%
len(all_tweets)
# Out:
# 1000
